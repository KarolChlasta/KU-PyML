# %% [markdown]
# <a href="https://colab.research.google.com/github/KarolChlasta/KU-PyML/blob/main/ThomasDuverneixLong-Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
f = open('/content/RetNet40-0-column.spike', 'r')
file_contents = f.read()
print (file_contents)
# Out:
# /column_net_1_5_3_10/soma/spike     0.009250
# /column_net_1_1_1_17/soma/spike     0.009700
# /column_net_1_1_2_21/soma/spike     0.009700
# /column_net_1_1_3_13/soma/spike     0.009700
# /column_net_1_1_6_24/soma/spike     0.009700
# /column_net_1_1_8_2/soma/spike     0.009700
# /column_net_1_2_2_15/soma/spike     0.009700
# /column_net_1_2_3_22/soma/spike     0.009700
# /column_net_1_2_7_25/soma/spike     0.009700
# /column_net_1_2_8_2/soma/spike     0.009700
# /column_net_1_3_2_16/soma/spike     0.009700
# /column_net_1_3_4_13/soma/spike     0.009700
# /column_net_1_3_5_15/soma/spike     0.009700
# /column_net_1_4_5_13/soma/spike     0.009700
# /column_net_1_4_6_9/soma/spike     0.009700
# /column_net_1_4_8_23/soma/spike     0.009700
# /column_net_1_5_2_6/soma/spike     0.009700
# /column_net_1_5_2_13/soma/spike     0.009700
# /column_net_1_5_7_2/soma/spike     0.009700
# /column_net_1_3_4_18/soma/spike     0.010800
# /column_net_1_5_1_12/soma/spike     0.010800
# ...

# %%
#Understanding what the input and output features are

print(spike.feature_names)
print(iris.target_names)


#Reading the data

spike.data

#Reading the target (the output variable)

spike.target

#Assigning names to the input and output variables

X = spike.data
Y = spike.target

#Analyzing the data dimensions

X.shape
Y.shape

#Using Random Forest to classify the data

clf = RandomForestClassifier()

clf.fit(X, Y)

#Describing which features are useful with variable importance

print(clf.feature_importances_)

#Making predictions

X[1]

#I don’t have the data but let’s imagine that the output is something like this
Out => array ([4.3, 2.6, 1.1, 0.5])

print(clf.predict([[4.3, 2.6, 1.1, 0.5]]))

print(clf.predict(X[[1]]))

print(clf.predict_proba(X[[1]]))

clf.fit(spike.data, spike.target_names[spike.target])

#Splitting the data with a 70/30 ratio

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

X_train.shape, Y_train.shape

X_test.shape, Y_test.shape

#Reconstructing the Random Forest

clf.fit(X_train, Y_train)

#Making predicitions on a single sample from the spike data set

print(clf.predict([[4.3, 2.6, 1.1, 0.5]]))

print(clf.predict_proba([[4.3, 2.6, 1.1, 0.5]]))

#Making predicitions on the test set and comparing predicted with actual values

#predicted value

print(clf.predict(X_test))

#actual value

print(Y_test)

#Rating the performance of the classifying model

print(clf.score(X_test, Y_test))
